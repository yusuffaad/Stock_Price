# %% [markdown]
# <a href="https://colab.research.google.com/github/yusuffaad/Stock_Price/blob/main/Stock_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import json

# %%
apple =yf.Ticker('AAPL')

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/apple.json
# Out:
# --2025-06-01 16:09:31--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/apple.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5699 (5.6K) [application/json]
# Saving to: ‘apple.json’
#
# apple.json          100%[===================>]   5.57K  --.-KB/s    in 0s
#
# 2025-06-01 16:09:31 (1.13 GB/s) - ‘apple.json’ saved [5699/5699]

# %%
#Stock infl
with open('apple.json') as json_file:
  apple_info = json.load(json_file)
  print(type(apple_info))
apple_info
# Out:
# <class 'dict'>
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
apple_info['country']
# Out:
# 'United States'

# %%
#Extracting stock price histoy
apple_stock_data = apple.history(period='max')
apple_stock_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1980-12-12 00:00:00-05:00  0.098597  0.099025  0.098597  0.098597  469033600
# 1980-12-15 00:00:00-05:00  0.093881  0.093881  0.093453  0.093453  175884800
# 1980-12-16 00:00:00-05:00  0.087022  0.087022  0.086594  0.086594  105728000
# 1980-12-17 00:00:00-05:00  0.088737  0.089165  0.088737  0.088737   86441600
# 1980-12-18 00:00:00-05:00  0.091310  0.091738  0.091310  0.091310   73449600
#
#                            Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00        0.0           0.0
# 1980-12-15 00:00:00-05:00        0.0           0.0
# 1980-12-16 00:00:00-05:00        0.0           0.0
# 1980-12-17 00:00:00-05:00        0.0           0.0
# 1980-12-18 00:00:00-05:00        0.0           0.0

# %%
#Resetting the index
apple_stock_data.reset_index(inplace=True)

# %%
apple_stock_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 1980-12-12 00:00:00-05:00  0.098597  0.099025  0.098597  0.098597
# 1 1980-12-15 00:00:00-05:00  0.093881  0.093881  0.093453  0.093453
# 2 1980-12-16 00:00:00-05:00  0.087022  0.087022  0.086594  0.086594
# 3 1980-12-17 00:00:00-05:00  0.088737  0.089165  0.088737  0.088737
# 4 1980-12-18 00:00:00-05:00  0.091310  0.091738  0.091310  0.091310
#
#       Volume  Dividends  Stock Splits
# 0  469033600        0.0           0.0
# 1  175884800        0.0           0.0
# 2  105728000        0.0           0.0
# 3   86441600        0.0           0.0
# 4   73449600        0.0           0.0

# %%
apple_stock_data.plot(x='Date', y='Open')
# Out:
# <Axes: xlabel='Date'>

# %%
#Extracting dividends
apple_stock_data.Dividends.plot()
# Out:
# <Axes: >

# %%
#Extracting AMD stop price
amd = yf.Ticker('amd')

# %%
#Getting stock info
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/amd.json
with open('amd.json') as json_file2:
  amd_json = json.load(json_file2)
amd_json
# Out:
# --2025-06-01 16:27:25--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/amd.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5838 (5.7K) [application/json]
# Saving to: ‘amd.json.2’
#
# amd.json.2          100%[===================>]   5.70K  --.-KB/s    in 0s
#
# 2025-06-01 16:27:25 (1.42 GB/s) - ‘amd.json.2’ saved [5838/5838]
# {'zip': '95054',
#  'sector': 'Technology',
#  'fullTimeEmployees': 15500,
# ...

# %%
print(f'Country: {amd_json["country"]}')
print(f'Sector: {amd_json["sector"]}')
# Out:
# Country: United States
# Sector: Technology

# %%
#AMD stock price data
amd_stock_price = amd.history(period='max')
amd_stock_price.head()
# Out:
#                            Open      High       Low     Close  Volume  \
# Date
# 1980-03-17 00:00:00-05:00   0.0  3.302083  3.125000  3.145833  219600
# 1980-03-18 00:00:00-05:00   0.0  3.125000  2.937500  3.031250  727200
# 1980-03-19 00:00:00-05:00   0.0  3.083333  3.020833  3.041667  295200
# 1980-03-20 00:00:00-05:00   0.0  3.062500  3.010417  3.010417  159600
# 1980-03-21 00:00:00-05:00   0.0  3.020833  2.906250  2.916667  130800
#
#                            Dividends  Stock Splits
# Date
# 1980-03-17 00:00:00-05:00        0.0           0.0
# 1980-03-18 00:00:00-05:00        0.0           0.0
# 1980-03-19 00:00:00-05:00        0.0           0.0
# 1980-03-20 00:00:00-05:00        0.0           0.0
# 1980-03-21 00:00:00-05:00        0.0           0.0

# %%
amd_stock_price.reset_index(inplace=True)

# %%
amd.history(period='5d')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-05-23 00:00:00-04:00  108.089996  111.019997  107.669998  110.309998
# 2025-05-27 00:00:00-04:00  113.180000  115.400002  112.269997  114.559998
# 2025-05-28 00:00:00-04:00  114.919998  114.949997  112.660004  112.860001
# 2025-05-29 00:00:00-04:00  115.489998  115.540001  112.129997  113.029999
# 2025-05-30 00:00:00-04:00  111.580002  112.110001  108.620003  110.730003
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-05-23 00:00:00-04:00  30867300        0.0           0.0
# 2025-05-27 00:00:00-04:00  37885000        0.0           0.0
# 2025-05-28 00:00:00-04:00  27483700        0.0           0.0
# 2025-05-29 00:00:00-04:00  30501400        0.0           0.0
# 2025-05-30 00:00:00-04:00  36046200        0.0           0.0

# %% [markdown]
# ##WEB SCRAPING

# %%
#Libraries
import requests, html5lib, plotly, lxml
from bs4 import BeautifulSoup

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#Sending an HTML request
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html"
page = requests.get(url).text

# %%
#Parsing HTML Content
soup = BeautifulSoup(page, 'html.parser')

# %%
#Identifying html tags
netflix_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

for row in soup.find("tbody").find_all('tr'):
    col = row.find_all("td")
    date = col[0].text
    Open = col[1].text
    high = col[2].text
    low = col[3].text
    close = col[4].text
    adj_close = col[5].text
    volume = col[6].text
    netflix_data = pd.concat([netflix_data, pd.DataFrame({"Date":[date], "Open":[Open], "High":[high], "Low":[low], "Close":[close], "Adj Close":[adj_close], "Volume":[volume]})], ignore_index=True)

# %%
netflix_data.head()
# Out:
#            Date    Open    High     Low   Close       Volume Adj Close
# 0  Jun 01, 2021  504.01  536.13  482.14  528.21   78,560,600    528.21
# 1  May 01, 2021  512.65  518.95  478.54  502.81   66,927,600    502.81
# 2  Apr 01, 2021  529.93  563.56  499.00  513.47  111,573,300    513.47
# 3  Mar 01, 2021  545.57  556.99  492.85  521.66   90,183,900    521.66
# 4  Feb 01, 2021  536.79  566.65  518.28  538.85   61,902,300    538.85

# %%
read_html_pandas_data = pd.read_html(url)
netflix_dataframe = read_html_pandas_data[0]

netflix_dataframe.head()
# Out:
#            Date    Open    High     Low  Close* Adj Close**     Volume
# 0  Jun 01, 2021  504.01  536.13  482.14  528.21      528.21   78560600
# 1  May 01, 2021  512.65  518.95  478.54  502.81      502.81   66927600
# 2  Apr 01, 2021  529.93  563.56  499.00  513.47      513.47  111573300
# 3  Mar 01, 2021  545.57  556.99  492.85  521.66      521.66   90183900
# 4  Feb 01, 2021  536.79  566.65  518.28  538.85      538.85   61902300

# %% [markdown]
# #Amazon Data

# %%
#Sending an HTML request
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html'
data = requests.get(url).text
#Parsing HTML content
soup = BeautifulSoup(data, 'html.parser')

# %%
# Extract the content of the title tag
print(soup('title'))
# Out:
# [<title>Amazon.com, Inc. (AMZN) Stock Historical Prices &amp; Data - Yahoo Finance</title>]

# %%
#Identifying the HTML tags
amazon_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

for row in soup.find("tbody").find_all('tr'):
    col = row.find_all("td")
    date = col[0].text
    Open = col[1].text
    high = col[2].text
    low = col[3].text
    close = col[4].text
    adj_close = col[5].text
    volume = col[6].text
    amazon_data = pd.concat([amazon_data, pd.DataFrame({"Date":[date], "Open":[Open], "High":[high], "Low":[low], "Close":[close], "Adj Close":[adj_close], "Volume":[volume]})], ignore_index=True)

# %%
amazon_data
# Out:
#             Date      Open      High       Low     Close       Volume  \
# 0   Jan 01, 2021  3,270.00  3,363.89  3,086.00  3,206.20   71,528,900
# 1   Dec 01, 2020  3,188.50  3,350.65  3,072.82  3,256.93   77,556,200
# 2   Nov 01, 2020  3,061.74  3,366.80  2,950.12  3,168.04   90,810,500
# 3   Oct 01, 2020  3,208.00  3,496.24  3,019.00  3,036.15  116,226,100
# 4   Sep 01, 2020  3,489.58  3,552.25  2,871.00  3,148.73  115,899,300
# ..           ...       ...       ...       ...       ...          ...
# 56  May 01, 2016    663.92    724.23    656.00    722.79   90,614,500
# 57  Apr 01, 2016    590.49    669.98    585.25    659.59   78,464,200
# 58  Mar 01, 2016    556.29    603.24    538.58    593.64   94,009,500
# 59  Feb 01, 2016    578.15    581.80    474.00    552.52  124,144,800
# 60  Jan 01, 2016    656.29    657.72    547.18    587.00  130,200,900
#
#    Adj Close
# 0   3,206.20
# 1   3,256.93
# 2   3,168.04
# 3   3,036.15
# 4   3,148.73
# ..       ...
# 56    722.79
# ...
